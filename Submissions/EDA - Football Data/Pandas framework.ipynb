# %%
import pandas as pd

# %%
list_df = [[32, 'Portugal', 94], [30, 'Argentina', 93], [25 , 'Brazil', 92]]

# %%
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# %%
columns = ['Age', 'Nationality', 'Overall']

# %%
pd.DataFrame(data=list_df, index=index, columns=columns)
# Out:
#                     Age Nationality  Overall
# Christiano Ronaldo   32    Portugal       94
# Lionel Messi         30   Argentina       93
# Neymar               25      Brazil       92

# %%
dict_df = {'Age':[32, 30, 25], 'Nationality':['Portugal', 'Argentina', 'Brazil'], 'Overall':[94, 93, 92]}

# %%
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# %%
pd.DataFrame(data=dict_df, index=index)
# Out:
#                     Age Nationality  Overall
# Christiano Ronaldo   32    Portugal       94
# Lionel Messi         30   Argentina       93
# Neymar               25      Brazil       92

# %%
import numpy as np

# %%
array_df = np.array([[32, 'Portugal', 94], [30, 'Argentina', 93], [25 , 'Brazil', 92]])

# %%
index = ['Christiano Ronaldo', 'Lionel Messi', 'Neymar']

# %%
columns = ['Age', 'Nationality', 'Overall']

# %%
pd.DataFrame(data=array_df, index=index, columns=columns)
# Out:
#                    Age Nationality Overall
# Christiano Ronaldo  32    Portugal      94
# Lionel Messi        30   Argentina      93
# Neymar              25      Brazil      92

# %%
load_df = pd.read_csv('football_players.csv', index_col='Name')
# Out:
# C:\Users\Mbushe Holdings\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (14,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
load_df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df = pd.DataFrame(load_df)

# %%
df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df.iloc[4]
# Out:
# Age                         31
# Nationality            Germany
# Overall                     92
# Acceleration            58
# Aggression              29
# Agility                 52
# Balance                 35
# Ball control            48
# Composure               70
# Crossing                15
# Curve                   14
# Dribbling               30
# Finishing               13
# Free kick accuracy      11
# GK diving               91
# GK handling             90
# GK kicking              95
# GK positioning          91
# GK reflexes             89
# Heading accuracy        25
# Interceptions           30
# Jumping                 78
# Long passing            59
# Long shots              16
# Marking                 10
# Penalties               47
# Positioning             12
# Reactions               85
# Short passing           55
# Shot power              25
# Sliding tackle          11
# Sprint speed            61
# Stamina                 44
# Standing tackle         10
# Strength                83
# Vision                  70
# Volleys                 11
# Preferred Positions        GK
# Name: M. Neuer, dtype: object

# %%
df.iloc[4:10]
# Out:
#                 Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# M. Neuer         31     Germany       92       58         29      52
# R. Lewandowski   28      Poland       91       79         80      78
# De Gea           26       Spain       90       57         38      60
# E. Hazard        26     Belgium       90       93         54      93
# T. Kroos         27     Germany       90       60         60      71
# G. Higuaín       29   Argentina       90       78         50      75
#
#                Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                    ...
# M. Neuer        35           48        70       15      ...        55
# R. Lewandowski  80           89        87       62      ...        83
# De Gea          43           42        64       17      ...        50
# E. Hazard       91           92        87       80      ...        86
# T. Kroos        69           89        85       85      ...        90
# G. Higuaín      69           85        86       68      ...        75
#
#                Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# M. Neuer           25             11           61      44              10
# R. Lewandowski     88             19           83      79              42
# De Gea             31             13           58      40              21
# E. Hazard          79             22           87      79              27
# T. Kroos           87             69           52      77              82
# G. Higuaín         88             18           80      72              22
#
#                Strength  Vision Volleys Preferred Positions
# Name
# M. Neuer         83      70      11                     GK
# R. Lewandowski   84      78      87                     ST
# De Gea           64      68      13                     GK
# E. Hazard        65      86      79                     LW
# T. Kroos         74      88      82                 CDM CM
# G. Higuaín       85      70      88                     ST
#
# [6 rows x 38 columns]

# %%
df.loc['M. Neuer']
# Out:
# Age                         31
# Nationality            Germany
# Overall                     92
# Acceleration            58
# Aggression              29
# Agility                 52
# Balance                 35
# Ball control            48
# Composure               70
# Crossing                15
# Curve                   14
# Dribbling               30
# Finishing               13
# Free kick accuracy      11
# GK diving               91
# GK handling             90
# GK kicking              95
# GK positioning          91
# GK reflexes             89
# Heading accuracy        25
# Interceptions           30
# Jumping                 78
# Long passing            59
# Long shots              16
# Marking                 10
# Penalties               47
# Positioning             12
# Reactions               85
# Short passing           55
# Shot power              25
# Sliding tackle          11
# Sprint speed            61
# Stamina                 44
# Standing tackle         10
# Strength                83
# Vision                  70
# Volleys                 11
# Preferred Positions        GK
# Name: M. Neuer, dtype: object

# %%
df['Age']
# Out:
# Name
# Cristiano Ronaldo    32
# L. Messi             30
# Neymar               25
# L. Suárez            30
# M. Neuer             31
# R. Lewandowski       28
# De Gea               26
# E. Hazard            26
# T. Kroos             27
# G. Higuaín           29
# Sergio Ramos         31
# K. De Bruyne         26
# T. Courtois          25
# A. Sánchez           28
# L. Modrić            31
# G. Bale              27
# S. Agüero            29
# G. Chiellini         32
# G. Buffon            39
# P. Dybala            23
# J. Oblak             24
# A. Griezmann         26
# Thiago               26
# P. Aubameyang        28
# L. Bonucci           30
# J. Boateng           28
# D. Godín             31
# M. Hummels           28
# M. Özil              28
# H. Lloris            30
#                      ..
# M. Hurst             21
# A. Osmanoski         17
# K. Cotter            18
# T. Robinson          19
# R. Hughes            18
# Z. Mohammed          17
# D. Peppard           17
# C. Rogers            17
# N. McLaughlin        18
# L. Kiely             18
# J. Latibeaudiere     17
# J. Payne             18
# G. Manley            19
# P. Phillips          18
# A. Byrne             18
# K. Fujikawa          18
# K. Egan              19
# T. Brownsword        17
# F. Prohart           18
# A. Kilgour           19
# R. White             18
# A. Conway            19
# T. Sawyer            18
# J. Keeble            18
# T. Käßemodel         28
# A. Kelsey            17
# B. Richardson        47
# J. Young             17
# J. Lundstram         18
# L. Sackey            18
# Name: Age, Length: 17981, dtype: int64

# %%
df[['Age', 'Nationality']]
# Out:
#                    Age          Nationality
# Name
# Cristiano Ronaldo   32             Portugal
# L. Messi            30            Argentina
# Neymar              25               Brazil
# L. Suárez           30              Uruguay
# M. Neuer            31              Germany
# R. Lewandowski      28               Poland
# De Gea              26                Spain
# E. Hazard           26              Belgium
# T. Kroos            27              Germany
# G. Higuaín          29            Argentina
# Sergio Ramos        31                Spain
# K. De Bruyne        26              Belgium
# T. Courtois         25              Belgium
# A. Sánchez          28                Chile
# L. Modrić           31              Croatia
# G. Bale             27                Wales
# S. Agüero           29            Argentina
# G. Chiellini        32                Italy
# G. Buffon           39                Italy
# P. Dybala           23            Argentina
# J. Oblak            24             Slovenia
# A. Griezmann        26               France
# Thiago              26                Spain
# P. Aubameyang       28                Gabon
# L. Bonucci          30                Italy
# J. Boateng          28              Germany
# D. Godín            31              Uruguay
# M. Hummels          28              Germany
# M. Özil             28              Germany
# H. Lloris           30               France
# ...                ...                  ...
# M. Hurst            21             Scotland
# A. Osmanoski        17        FYR Macedonia
# K. Cotter           18              England
# T. Robinson         19              England
# R. Hughes           18             Scotland
# Z. Mohammed         17              England
# D. Peppard          17  Republic of Ireland
# C. Rogers           17  Republic of Ireland
# N. McLaughlin       18             Scotland
# L. Kiely            18  Republic of Ireland
# J. Latibeaudiere    17              England
# J. Payne            18              England
# G. Manley           19  Republic of Ireland
# P. Phillips         18  Republic of Ireland
# A. Byrne            18  Republic of Ireland
# K. Fujikawa         18                Japan
# K. Egan             19              England
# T. Brownsword       17              England
# F. Prohart          18              Austria
# A. Kilgour          19              England
# R. White            18              England
# A. Conway           19  Republic of Ireland
# T. Sawyer           18              England
# J. Keeble           18              England
# T. Käßemodel        28              Germany
# A. Kelsey           17              England
# B. Richardson       47              England
# J. Young            17             Scotland
# J. Lundstram        18              England
# L. Sackey           18                Ghana
#
# [17981 rows x 2 columns]

# %%
df.iloc[0:5][['Age', 'Nationality']]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
df[['Age', 'Nationality']].iloc[0:5]
# Out:
#                    Age Nationality
# Name
# Cristiano Ronaldo   32    Portugal
# L. Messi            30   Argentina
# Neymar              25      Brazil
# L. Suárez           30     Uruguay
# M. Neuer            31     Germany

# %%
df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df[df.Age == df.Age.max()]
# Out:
#                Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# B. Richardson   47     England       46       25         44      35
#
#               Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                   ...
# B. Richardson  44           22        44       11      ...        12
#
#               Shot power Sliding tackle Sprint speed Stamina Standing tackle  \
# Name
# B. Richardson     13             13           25      32              12
#
#               Strength  Vision Volleys Preferred Positions
# Name
# B. Richardson   47      17      12                     GK
#
# [1 rows x 38 columns]

# %%
df[df.Overall ==df.Overall.max()]
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
#
# [1 rows x 38 columns]

# %%
# %matplotlib inline

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000F35AE87B70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000F35BAE7B00>]],
#       dtype=object)

# %%
df.head()
# Out:
#                    Age Nationality  Overall Acceleration Aggression Agility  \
# Name
# Cristiano Ronaldo   32    Portugal       94       89         63      89
# L. Messi            30   Argentina       93       92         48      90
# Neymar              25      Brazil       92       94         56      96
# L. Suárez           30     Uruguay       92       88         78      86
# M. Neuer            31     Germany       92       58         29      52
#
#                   Balance Ball control Composure Crossing  ... Short passing  \
# Name                                                       ...
# Cristiano Ronaldo  63           93        95       85      ...        83
# L. Messi           95           95        96       77      ...        88
# Neymar             82           95        92       75      ...        81
# L. Suárez          60           91        83       77      ...        83
# M. Neuer           35           48        70       15      ...        55
#
#                   Shot power Sliding tackle Sprint speed Stamina  \
# Name
# Cristiano Ronaldo     94             23           91      92
# L. Messi              85             26           87      73
# Neymar                80             33           90      78
# L. Suárez             87             38           77      89
# M. Neuer              25             11           61      44
#
#                   Standing tackle Strength  Vision Volleys Preferred Positions
# Name
# Cristiano Ronaldo          31       80      85      88                  ST LW
# L. Messi                   28       59      90      85                     RW
# Neymar                     24       53      80      83                     LW
# L. Suárez                  45       80      84      88                     ST
# M. Neuer                   10       83      70      11                     GK
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 38 columns):
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Acceleration           17981 non-null object
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# GK handling            17981 non-null object
# GK kicking             17981 non-null object
# GK positioning         17981 non-null object
# GK reflexes            17981 non-null object
# Heading accuracy       17981 non-null object
# Interceptions          17981 non-null object
# Jumping                17981 non-null object
# Long passing           17981 non-null object
# Long shots             17981 non-null object
# Marking                17981 non-null object
# Penalties              17981 non-null object
# Positioning            17981 non-null object
# Reactions              17981 non-null object
# Short passing          17981 non-null object
# Shot power             17981 non-null object
# Sliding tackle         17981 non-null object
# Sprint speed           17981 non-null object
# Stamina                17981 non-null object
# Standing tackle        17981 non-null object
# Strength               17981 non-null object
# Vision                 17981 non-null object
# Volleys                17981 non-null object
# Preferred Positions    17981 non-null object
# dtypes: int64(2), object(36)
# memory usage: 6.0+ MB

# %%
df.Acceleration = pd.to_numeric(df.Acceleration, errors = "coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17981 entries, Cristiano Ronaldo to L. Sackey
# Data columns (total 38 columns):
# Age                    17981 non-null int64
# Nationality            17981 non-null object
# Overall                17981 non-null int64
# Acceleration           17926 non-null float64
# Aggression             17981 non-null object
# Agility                17981 non-null object
# Balance                17981 non-null object
# Ball control           17981 non-null object
# Composure              17981 non-null object
# Crossing               17981 non-null object
# Curve                  17981 non-null object
# Dribbling              17981 non-null object
# Finishing              17981 non-null object
# Free kick accuracy     17981 non-null object
# GK diving              17981 non-null object
# GK handling            17981 non-null object
# GK kicking             17981 non-null object
# GK positioning         17981 non-null object
# GK reflexes            17981 non-null object
# Heading accuracy       17981 non-null object
# Interceptions          17981 non-null object
# Jumping                17981 non-null object
# Long passing           17981 non-null object
# Long shots             17981 non-null object
# Marking                17981 non-null object
# Penalties              17981 non-null object
# Positioning            17981 non-null object
# Reactions              17981 non-null object
# Short passing          17981 non-null object
# Shot power             17981 non-null object
# Sliding tackle         17981 non-null object
# Sprint speed           17981 non-null object
# Stamina                17981 non-null object
# Standing tackle        17981 non-null object
# Strength               17981 non-null object
# Vision                 17981 non-null object
# Volleys                17981 non-null object
# Preferred Positions    17981 non-null object
# dtypes: float64(1), int64(2), object(35)
# memory usage: 6.0+ MB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000F35BB6E4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000F35CC45128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000F35CC7E748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000F35CC2ECF8>]],
#       dtype=object)

# %%
df.sort_values("Acceleration", ascending = False)
# Out:
#                   Age        Nationality  Overall  Acceleration Aggression  \
# Name
# Maicón             27             Brazil       76       33270.0     63
# G. McCleary        30            Jamaica       73       32540.0     55
# D. Powell          26            England       64       32540.0     39
# J. Parker          26  Antigua & Barbuda       59       31048.0     44
# Iban Salvador      21  Equatorial Guinea       69       30011.0      60+12
# T. Kongolo         23        Netherlands       77       28887.0     72
# Z. Bakayogo        30        Ivory Coast       63       27760.0     69
# A. Gomes           16            England       64       27546.0     36
# O. Tufan           22             Turkey       76       27089.0     78
# K. Hansen          28            Denmark       71       25993.0     64
# S. O'Neill         23      United States       66       25600.0  24504
# B. Walker          21            England       61       24838.0     61
# A. Tettey          31             Norway       72       24108.0     86
# M. Álvarez         25            Germany       64       24016.0     47
# P. Groß            26            Germany       76       23774.0     66
# J. Egan            18            England       50       23498.0     33
# M. Lorentzson      32             Sweden       64       23437.0     67
# B. Kessel          29            Germany       70       23408.0     78
# S. Mattila         27            Finland       65       21947.0     70
# N. Czornomaz       21          Argentina       58       21551.0  43130
# Carlos Hernández   26              Spain       72       21459.0     70
# J. De Sart         22            Belgium       70       20911.0     74
# N. Valentini       28          Argentina       68       20302.0     68
# Y. Toyoda          32              Japan       67       20090.0     62
# G. Hairemans       25            Belgium       67       18172.0     62
# V. Enyeama         34            Nigeria       80       17899.0     39
# M. Flynn           36              Wales       62       16103.0     64
# J. Blackman        23            England       67       15738.0       23+3
# J. Corona          36             Mexico       76       15128.0     11
# K. Manneh          22      United States       71          96.0     50
# ...               ...                ...      ...           ...        ...
# M. Spelmann        30            Denmark       67           NaN     85
# C. Dagnall         31            England       66           NaN     57
# A. Taylor          26              Wales       66           NaN     65
# M. Cash            19            England       66           NaN     51
# M. Schröter        21            Germany       65           NaN     70
# B. Smith           23          Australia       65           NaN     70
# J. Bolingi         23           DR Congo       65           NaN     65
# A. Fukuta          25              Japan       64           NaN     68
# M. Udol            21             France       64           NaN     63
# Manel Royo         23              Spain       64           NaN     64
# L. Zidane          19             France       64           NaN     16
# G. Wylde           26           Scotland       64           NaN     59
# J. Clarke-Salter   19            England       63           NaN       49+4
# M. Heider          31            Germany       62           NaN     60
# F. Obilor          26            Nigeria       62           NaN     72
# K. Kitagawa        20              Japan       62           NaN     51
# Marlinho           23             Brazil       62           NaN     48
# I. Ganago          18           Cameroon       61           NaN     32
# K. Scott           19      United States       60           NaN       48+2
# G. Guessan         24        Ivory Coast       60           NaN     51
# J. Morias          21            Jamaica       60           NaN     63
# Gonzalo Pereira    20              Spain       60           NaN       57+1
# B. White           19            England       59           NaN     67
# M. Cortés          20           Colombia       59           NaN     55
# J. Schneider       23            Germany       59           NaN     43
# A. Fletcher        18            England       57           NaN     49
# D. Yearwood        17            England       55           NaN     38
# A. Ammitzbøl       18            Denmark       55           NaN     38
# E. Bwomono         18            England       54           NaN     52
# P. Ng              21            England       51           NaN     48
#
#                     Agility    Balance Ball control  Composure   Crossing  \
# Name
# Maicón               85         64             70+1     66         76
# G. McCleary       27820         66        26330         59         67
# D. Powell            66         43           63         59         52
# J. Parker            69         71           59         67         59
# Iban Salvador        83         80           71         54         64
# T. Kongolo           75         63           69         73         67
# Z. Bakayogo          71         63           60      23743         59
# A. Gomes             82         90           66         57         61
# O. Tufan             76         69           76         76         68
# K. Hansen            75         71           67      23437         65
# S. O'Neill           57           49+2       63         59         46
# B. Walker            73         72             61+1     69         43
# A. Tettey         25600         74           63         66         60
# M. Álvarez        26024         74             67+6       55+4     47
# P. Groß                69+1     73           76         71           80+2
# J. Egan              51         73           48         42         48
# M. Lorentzson     24504         72        22313           63+3     55
# B. Kessel            54         56           67         65         65
# S. Mattila             62+1     51           62         57         63
# N. Czornomaz      18264      23043        23377      19025      23012
# Carlos Hernández  18476      19025        21610         65         33
# J. De Sart           64         71           65         73         66
# N. Valentini      17593         60           60         55         38
# Y. Toyoda            66         46        21582      24869         39
# G. Hairemans      22706         64             71+1     66           72+1
# V. Enyeama        21217         59           23         24         10
# M. Flynn          12816         60           64         62         53
# J. Blackman           46+13       33+4       25           28+4     13
# J. Corona         23377         60           20         67         17
# K. Manneh            85         80           68           68+2     59
# ...                     ...        ...          ...        ...        ...
# M. Spelmann            68+1     78           67         66         63
# C. Dagnall           72         75           64         67         42
# A. Taylor            63         60           50         46         22
# M. Cash                82+3     67           68         70         67
# M. Schröter          68         71           63         56         67
# B. Smith             75         75           56         58         77
# J. Bolingi             67+2     60             60+2     62         38
# A. Fukuta              72+1     80           66         42         59
# M. Udol              59         75           59         56         57
# Manel Royo             60+7       63+5        56+14     56          61+29
# L. Zidane              36+2       49+2       14         36         12
# G. Wylde             85         82           61         54         55
# J. Clarke-Salter       48+3     55             50+4       58+2     36
# M. Heider            60         57             61+4     63          58+11
# F. Obilor            49         46           44         55         27
# K. Kitagawa          65         57           45         61         25
# Marlinho             90         91           63         68         57
# I. Ganago            58           70+2       52           51+5     32
# K. Scott               72+1       73+5         63+3     62           56+3
# G. Guessan           61         57           50         42         28
# J. Morias              62+3     84             58+4       56+7     49
# Gonzalo Pereira        49+1       65+1    14246           44+1  11689
# B. White             48         49           42         52         36
# M. Cortés              63+3     70           59         52           45+9
# J. Schneider         65           77+2       56         51         43
# A. Fletcher            77+2  24929           54         56         51
# D. Yearwood          55         79           57         58         47
# A. Ammitzbøl         62         59           51         43         37
# E. Bwomono           56         79            41+11     30           48+7
# P. Ng                41      21186             38+1       45+2       33+3
#
#                   ... Short passing Shot power Sliding tackle Sprint speed  \
# Name              ...
# Maicón            ...        73         74             21           89
# G. McCleary       ...        65         78             43        32174
# D. Powell         ...        61         67             17        32905
# J. Parker         ...     19146         48             28             95+2
# Iban Salvador     ...          64+3     71               18+3    28887
# T. Kongolo        ...        72         67             84        28216
# Z. Bakayogo       ...        59         45             63        26299
# A. Gomes          ...          63+3     61             20        25842
# O. Tufan          ...        76         80             71        25812
# K. Hansen         ...        71         55             74        26330
# S. O'Neill        ...        65         62             63        24929
# B. Walker         ...          60+1     61             56        25204
# A. Tettey         ...     25600         85             69        25965
# M. Álvarez        ...        58           65+3         21        24381
# P. Groß           ...        79         74             63             67+3
# J. Egan           ...        44         51             27        23316
# M. Lorentzson     ...        62      15797             65        21947
# B. Kessel         ...        67         65             73        23802
# S. Mattila        ...        64         72          19419           57
# N. Czornomaz      ...     22647      23377          12420        21217
# Carlos Hernández  ...     23408           58+9         73        20333
# J. De Sart        ...        67         73             67           60
# N. Valentini      ...        54         40             66            52-14
# Y. Toyoda         ...        54         68             17           54
# G. Hairemans      ...          70+3     67             48        20363
# V. Enyeama        ...        39         35             11        19360
# M. Flynn          ...        67         70             48        16862
# J. Blackman       ...        31         23             12        13789
# J. Corona         ...        33         21             11        13940
# K. Manneh         ...          67+7       80+6         29           92
# ...               ...           ...        ...            ...          ...
# M. Spelmann       ...        66         69             68             66+5
# C. Dagnall        ...        56         67             17        25204
# A. Taylor         ...        53         36             64           65
# M. Cash           ...        69         52               63+5        83+11
# M. Schröter       ...        62         51             60             77+7
# B. Smith          ...        62         40             58             85+5
# J. Bolingi        ...        51         65             20             74+4
# A. Fukuta         ...        65           55+1         54           74
# M. Udol           ...        60         34             63             78+5
# Manel Royo        ...          60+6     48             67            67+12
# L. Zidane         ...        22         15             13        11689
# G. Wylde          ...        63         70             42        31809
# J. Clarke-Salter  ...          54+6     44               67+2         64+2
# M. Heider         ...          59+8     60              31+10         70+5
# F. Obilor         ...        42         32             62             66+8
# K. Kitagawa       ...        60         55             34           78
# Marlinho          ...        55         52             51             75+3
# I. Ganago         ...        51         58             14             71+3
# K. Scott          ...          63+2       54+2         51             65+3
# G. Guessan        ...        43         60             23             70+3
# J. Morias         ...          42+1     69             28             74+2
# Gonzalo Pereira   ...     13516      16438               70+2         61+1
# B. White          ...         58+12     35             55             68+4
# M. Cortés         ...          61+2     56             39             76+1
# J. Schneider      ...        49         61             23             75+8
# A. Fletcher       ...        45         57             11        26724
# D. Yearwood       ...          58+4     49             42           69
# A. Ammitzbøl      ...        43         52             18            72+12
# E. Bwomono        ...         40+10     21               52+1        79+17
# P. Ng             ...        44         36             55             60+1
#
#                     Stamina Standing tackle   Strength     Vision    Volleys  \
# Name
# Maicón               79              29         70         63         62
# G. McCleary          71              52         73         67         71
# D. Powell            68              33      25934         46         49
# J. Parker            68              29         65         58         43
# Iban Salvador        68                17+2     56           65+5     56
# T. Kongolo           77              82         77         49         40
# Z. Bakayogo       26299              61      26696         53         35
# A. Gomes             58              19         34           63+7       57+1
# O. Tufan             81              75         75      24532         55
# K. Hansen            76           25965         74         63         36
# S. O'Neill           71              64      29221         54         42
# B. Walker              67+1          53         72           61+2     56
# A. Tettey            81              73         79         63      22737
# M. Álvarez           53              22          69+11       54+1       59+1
# P. Groß              90              64         74           78+2     61
# J. Egan              53              25         51         47         36
# M. Lorentzson     24504              66      19906         58      14946
# B. Kessel            73              74         81         52         40
# S. Mattila           68           23377         70         63         55
# N. Czornomaz      17533           43126      20090      18660      18994
# Carlos Hernández     74                72+1     79         42         27
# J. De Sart           81              68         64         70         69
# N. Valentini         66              68         82         23         18
# Y. Toyoda            59              28         79         44         53
# G. Hairemans         70              56         67         67         66
# V. Enyeama           35              12         71      20821         11
# M. Flynn          18841              49         73         64         48
# J. Blackman       43433              13         58          29+15     17
# J. Corona            25              13      19115         40         12
# K. Manneh            66              46           54+5     62         57
# ...                     ...             ...        ...        ...        ...
# M. Spelmann          91              66           76+2     64         47
# C. Dagnall           79              24         72         57         65
# A. Taylor            69              66         90         41         20
# M. Cash                79+8          62      17564         68         42
# M. Schröter          64              63         60         59         45
# B. Smith             78              60         63         50         23
# J. Bolingi            73+10          25         71         61         56
# A. Fukuta            76              60         57         64         44
# M. Udol              66              67         65         57         35
# Manel Royo             66+9       23802         82         30         35
# L. Zidane              52+7          11           50+3      45+24      6
# G. Wylde             69              45         62         62         53
# J. Clarke-Salter     66              68           68+3     34         30
# M. Heider             75+20           37+10     70           52+3     65
# F. Obilor            51              55         86         30         22
# K. Kitagawa          57              32         58         45         54
# Marlinho             56              41         33         58         45
# I. Ganago            58              17           71+3     48         48
# K. Scott               60+4          52           37+5       66+1     48
# G. Guessan           57              18         76         49         46
# J. Morias            64              25         90         43           51+7
# Gonzalo Pereira        62+1          73      20090           37+1  12055
# B. White              73+22          58           69+8     40         21
# M. Cortés            59              34         57         53         34
# J. Schneider         50              20           66+6     47         62
# A. Fletcher          60              18         53         41         60
# D. Yearwood           78+38          39           47+9     50         39
# A. Ammitzbøl         56              14         52         40         34
# E. Bwomono           64                54+7      48+12     35         29
# P. Ng                57              54         62           30+1     29
#
#                  Preferred Positions
# Name
# Maicón                     RM ST LM
# G. McCleary                ST RM RW
# D. Powell                     RM LM
# J. Parker                     RM ST
# Iban Salvador          LM RM ST CAM
# T. Kongolo                    CB LB
# Z. Bakayogo                      LB
# A. Gomes               CM RW LW CAM
# O. Tufan                     CM CDM
# K. Hansen                        CB
# S. O'Neill                    RB CB
# B. Walker                     CB CM
# A. Tettey                    CM CDM
# M. Álvarez                CAM ST CF
# P. Groß                   LM CM CAM
# J. Egan                          RM
# M. Lorentzson                    RB
# B. Kessel                     RM RB
# S. Mattila                   CM CDM
# N. Czornomaz                     LM
# Carlos Hernández                 CB
# J. De Sart                   CM CDM
# N. Valentini                     CB
# Y. Toyoda                        ST
# G. Hairemans                 CM CAM
# V. Enyeama                       GK
# M. Flynn                         CM
# J. Blackman                      GK
# J. Corona                        GK
# K. Manneh               ST CF RM LM
# ...                              ...
# M. Spelmann                ST CM RM
# C. Dagnall                    RW ST
# A. Taylor                        CB
# M. Cash                   CAM RM CM
# M. Schröter                   RM RB
# B. Smith                     LWB LB
# J. Bolingi                       ST
# A. Fukuta                        CM
# M. Udol                          LB
# Manel Royo                    CB LB
# L. Zidane                        GK
# G. Wylde                         LM
# J. Clarke-Salter                 CB
# M. Heider                     ST RM
# F. Obilor                        CB
# K. Kitagawa                      ST
# Marlinho                      RM LM
# I. Ganago                        ST
# K. Scott                         CM
# G. Guessan                       ST
# J. Morias                     RM ST
# Gonzalo Pereira              CDM CB
# B. White                         CB
# M. Cortés                    LM CAM
# J. Schneider                     ST
# A. Fletcher                      ST
# D. Yearwood                      CM
# A. Ammitzbøl                     ST
# E. Bwomono                       RB
# P. Ng                         CB RB
#
# [17981 rows x 38 columns]

# %%
df_filtered = df[df.Acceleration <=100]

# %%
df_filtered.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000F35BBC8BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000F35DE79198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000F35DEA82E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000F35DEDD6A0>]],
#       dtype=object)

# %%
df_filtered.groupby("Age").mean().reset_index().plot.scatter("Age", "Acceleration")

# %%
# !pip install pandas profiling

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(df_filtered[["Age","Overall","Acceleration","Nationality"]])
